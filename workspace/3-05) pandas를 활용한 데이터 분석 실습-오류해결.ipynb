# %%
! pip install matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (D:\anaconda3_2\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\anaconda3_2\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\anaconda3_2\Lib\site-packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# File D:\anaconda3_2\Lib\site-packages\matplotlib\pyplot.py:57
#      55 from cycler import cycler  # noqa: F401
#      56 import matplotlib
# ---> 57 import matplotlib.colorbar
#      58 import matplotlib.image
#      59 from matplotlib import _api
#
# File D:\anaconda3_2\Lib\site-packages\matplotlib\colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File D:\anaconda3_2\Lib\site-packages\matplotlib\cbook.py:432
#     426         else:
#     427             return "<an empty list>"
# ...

# %%
df = pd.read_csv('./data/loan.csv', sep=',')
# Out:
# C:\Users\human3_02\AppData\Local\Temp\ipykernel_12376\609983660.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/loan.csv', sep=',')

# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\anaconda3_2\Lib\site-packages\matplotlib\backends\registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File D:\anaconda3_2\Lib\site-packages\matplotlib\backends\registry.py:365, in BackendRegistry.resolve_backend(self, backend)
#     364 if gui == "unknown":
# --> 365     gui = self._get_gui_framework_by_loading(backend)
#     366     self._backend_to_gui_framework[backend] = gui
#
# File D:\anaconda3_2\Lib\site-packages\matplotlib\backends\registry.py:124, in BackendRegistry._get_gui_framework_by_loading(self, backend)
#     120 def _get_gui_framework_by_loading(self, backend):
#     121     # Determine GUI framework for a backend by loading its module and reading the
# ...
