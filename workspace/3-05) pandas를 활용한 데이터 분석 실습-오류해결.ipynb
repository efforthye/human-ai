# %%
! pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/loan.csv', sep=',')
# Out:
# C:\Users\human3_02\AppData\Local\Temp\ipykernel_4736\609983660.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/loan.csv', sep=',')
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv('./data/loan.csv', sep=',')
#
# ...

# %%
# %matplotlib inline
